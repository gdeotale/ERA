# %%
! ls
# Out:
# config.py  dataset.py  model.py  s15.ipynb  train.py

# %%
# !pip install torchtext==0.12.0 datasets tensorboardX

# %%
from config import get_config

cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

# %%
from train import train_model
train_model(cfg)
# Out:
# Using device:  cuda
# Downloading builder script:   0%|          | 0.00/6.08k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/161k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/20.5k [00:00<?, ?B/s]
# Downloading and preparing dataset opus_books/en-it to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf...
# Downloading data:   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Max length of source sentence: 309
# Max length of target sentence: 274
# Processing Epoch 00: 100%|██████████| 4850/4850 [10:56<00:00,  7.39it/s, loss=5.685]
# --------------------------------------------------------------------------------
#     SOURCE: He gave us the required assurance, and we thanked him, but he still hung about, and seemed to be dissatisfied, so we asked him if there was anything further that we could do for him; and Harris, who is of a chummy disposition, offered him a bit of bread and jam.
#     TARGET: Egli ci diede l’assicurazione richiesta, e noi lo ringraziammo; ma continuò a gironzarci intorno, e siccome pareva poco soddisfatto, gli domandammo se potessimo fare qualche altra cosa per lui; e Harris, ch’è d’istinti ospitali, gli offerse un pezzo di pane col prosciutto.
#  PREDICTED: E la sua cosa , e la sua volta , e la sua sua , e non si era stato in un ’ altra volta , e non si era stato in un ’ altra cosa , e non non si era stato in un ’ altro che non si era stato in un ’ altra cosa .
# --------------------------------------------------------------------------------
#     SOURCE: I got on to her crib and kissed her: her forehead was cold, and her cheek both cold and thin, and so were her hand and wrist; but she smiled as of old.
#     TARGET: Mi accostai al letto e l'abbracciai; era fredda, ma sorrideva come per il passato.
#  PREDICTED: Non si era già già in un momento , e si mise a un ’ altra volta , e si mise a un ’ altra volta , e si mise a un ’ altra volta .
# --------------------------------------------------------------------------------
# Processing Epoch 01: 100%|██████████| 4850/4850 [10:51<00:00,  7.44it/s, loss=5.161]
# --------------------------------------------------------------------------------
#     SOURCE: 'Will you come and see me?' said the Countess after a pause. 'We must talk over something painful to you.
#     TARGET: — Venite da me — disse la contessa Lidija Ivanovna, dopo un certo silenzio; — dobbiamo parlare di una cosa triste per voi.
#  PREDICTED: — Vi piace , e mi piace ? — disse il viso . — Che cosa hai sentito ?
# --------------------------------------------------------------------------------
#     SOURCE: This would make his position more secure and durable, as it has made that of the Turk in Greece, who, notwithstanding all the other measures taken by him for holding that state, if he had not settled there, would not have been able to keep it.
#     TARGET: Questo farebbe più secura e più durabile quella possessione: come ha fatto el Turco, di Grecia; il quale, con tutti li altri ordini osservati da lui per tenere quello stato, se non vi fussi ito ad abitare, non era possibile che lo tenessi.
#  PREDICTED: , che , per le cose , e , e , che non si , e , e non si , e non si , non si , non si , non si , non si , non si , non si , non si .
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 4850/4850 [10:53<00:00,  7.42it/s, loss=5.416]
# --------------------------------------------------------------------------------
#     SOURCE: Then I should have asked you to accept my pledge of fidelity and to give me yours.
#     TARGET: "Allora vi avrei chiesto di accettare la promessa della mia fedeltà, Jane, e di darmi la vostra.
#  PREDICTED: Allora io ho fatto che vi la mia , e mi di .
# --------------------------------------------------------------------------------
#     SOURCE: "Good-night, Jane," he replied calmly.
#     TARGET: — Buona notte, Jane — mi rispose tranquillamente.
#  PREDICTED: — , Jane , — disse .
# --------------------------------------------------------------------------------
# Processing Epoch 03: 100%|██████████| 4850/4850 [10:55<00:00,  7.40it/s, loss=4.776]
# --------------------------------------------------------------------------------
#     SOURCE: 'What does it mean?
#     TARGET: «Che cosa vuol dire questo?
#  PREDICTED: — Che cosa c ’ è ?
# --------------------------------------------------------------------------------
#     SOURCE: I could not, in those days, see God for His creature: of whom I had made an idol.
#     TARGET: Il pensiero della creatura non mi riconduceva a quello di Dio, perché del mio sposo avevo fatto un idolo.
#  PREDICTED: Non potevo più più tempo di più di Dio , che mi aveva fatto il mio cuore , e che mi aveva fatto un ' altra volta .
# --------------------------------------------------------------------------------
# Processing Epoch 04: 100%|██████████| 4850/4850 [10:58<00:00,  7.37it/s, loss=4.159]
# --------------------------------------------------------------------------------
#     SOURCE: I know all that, but excuse me, do you know what has been accomplished in Europe with regard to the labour question?'
#     TARGET: Io so tutto questo, ma, perdonatemi, voi conoscete quel che è stato fatto in Europa a proposito della questione dell’organizzazione dei lavoratori?
#  PREDICTED: Io so che tutto è vero , ma che è stato in un ’ altra parte della società di un ’ altra parte della questione ?
# --------------------------------------------------------------------------------
#     SOURCE: At one moment she appeared to be in love with him, and at the next would turn cold, irritable, and impenetrable.
#     TARGET: Ella, un momento, era innamorata di lui, un momento, diventava fredda, irritabile e impenetrabile.
#  PREDICTED: A un tratto si sentiva bene che si fosse sempre in lui , e si sarebbe messo in mente il suo sguardo , e si , e si sentiva in fretta , e si sentiva in fretta , e si sentiva in fretta , e si sentiva di nuovo a un tratto .
# --------------------------------------------------------------------------------
# Processing Epoch 05: 100%|██████████| 4850/4850 [10:53<00:00,  7.42it/s, loss=4.618]
# --------------------------------------------------------------------------------
#     SOURCE: 'Yes, of course.'
#     TARGET: — Eh, s’intende.
#  PREDICTED: — Sì , ma è pronto .
# --------------------------------------------------------------------------------
#     SOURCE: But had he, and those who understood the matter in the 'right' way, been asked what this understanding amounted to, they would have been much puzzled how to reply.
#     TARGET: Ma se avessero chiesto a lui e a quelle persone che intendevano la cosa così “come si deve”, in che cosa consistesse questo loro intendere, e lui e queste persone si sarebbero trovate in difficoltà.
#  PREDICTED: Ma , e , che , con questi rapporti , aveva detto : “ Che cosa c ’ era , che cosa si sarebbe detto , come si sarebbe detto , si sarebbe detto , come si sarebbe detto .
# --------------------------------------------------------------------------------
# Processing Epoch 06: 100%|██████████| 4850/4850 [10:51<00:00,  7.44it/s, loss=3.636]
# --------------------------------------------------------------------------------
#     SOURCE: I need only think it over, and all will become clear.'
#     TARGET: Basterà pensare un po’ e tutto si chiarirà!”.
#  PREDICTED: Io voglio solo solo e non posso .
# --------------------------------------------------------------------------------
#     SOURCE: To the right of the door stood a bed on which sat the boy, his nightshirt unbuttoned, bending his little body backward, stretching himself and finishing his yawn.
#     TARGET: A destra della porta c’era un letto e sul letto era seduto, sollevato, il fanciullo con la sola camicina sbottonata, e, col corpicino piegato, si stiracchiava, mentre finiva uno sbadiglio.
#  PREDICTED: Per la porta , la porta , che sedeva accanto alla porta , la sua , la sua , la sua fisionomia , la sua , e la sua attenzione .
# --------------------------------------------------------------------------------
# Processing Epoch 07: 100%|██████████| 4850/4850 [10:52<00:00,  7.43it/s, loss=3.439]
# --------------------------------------------------------------------------------
#     SOURCE: The wind. obstinately, as if insisting on having its way, pushed Levin back and, tearing the leaves and blossoms off the lime trees and rudely and strangely uncovering the white branches of birches, bent everything in one direction: the acacias, the flowers, the dock leaves, the grass, and the crests of the trees.
#     TARGET: Il vento pareva insistere ostinatamente, fermava Levin e, strappando le foglie e i fiori dai tigli e rendendo spogli, informi e strani i rami bianchi delle betulle, piegava tutto da un sol lato: le acacie, i fiori, la bardana, l’erba e le cime degli alberi.
#  PREDICTED: Il vento , come se si , si , si , si , si i e i di un , con un movimento , e tutto il vento , tutto il rumore di neve , di sotto i prati , di neve e di sotto i prati .
# --------------------------------------------------------------------------------
#     SOURCE: 'And is there nothing by the way?'
#     TARGET: — E per strada non c’è nulla?
#  PREDICTED: — E non c ’ è nulla da fare ?
# --------------------------------------------------------------------------------
# Processing Epoch 08: 100%|██████████| 4850/4850 [10:51<00:00,  7.45it/s, loss=3.533]
# --------------------------------------------------------------------------------
#     SOURCE: 'So they were,' said the Dormouse; 'very ill.'
#     TARGET: — E infatti erano ammalate, — rispose il Ghiro, — gravemente ammalate.
#  PREDICTED: — E poi , — rispose il Ghiro .
# --------------------------------------------------------------------------------
#     SOURCE: When first he came to live at my expense, I never thought I should be able to get him to stop long.
#     TARGET: Dal primo giorno che cominciò a vivere a mie spese, pensai che non sarei stato in grado di tenerlo per molto tempo.
#  PREDICTED: Quando la prima volta fu terminata , non credeva che non avrei mai potuto .
# --------------------------------------------------------------------------------
# Processing Epoch 09: 100%|██████████| 4850/4850 [10:53<00:00,  7.43it/s, loss=3.270]
# --------------------------------------------------------------------------------
#     SOURCE: But you eat nothing: you have scarcely tasted since you began tea."
#     TARGET: Ma non mangiate nulla; avete appena assaggiato un crostino.
#  PREDICTED: Ma mangiato senza mangiare , e quando voi avete mangiato senza il tè .
# --------------------------------------------------------------------------------
#     SOURCE: "Then I should love Mrs. Reed, which I cannot do; I should bless her son John, which is impossible."
#     TARGET: — Allora dovrei voler bene alla signora Reed? Non posso.
#  PREDICTED: — Allora , signora Reed , la signora Reed , che non posso essere vostro figlio , e che voi non può essere né meno sua .
# --------------------------------------------------------------------------------
# Processing Epoch 10:   1%|          | 28/4850 [00:03<11:12,  7.17it/s, loss=3.224]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a2f9716b6210> in <module>
#       1 from train import train_model
# ----> 2 train_model(cfg)
#
# /mnt/prj002/Gunjan/ERA/Session14_transformers/torch/train.py in train_model(config)
#     240
#     241             # Backpropogate the loss
# --> 242             loss.backward()
#     243
#     244             # Update the weights
#
# /opt/conda/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
# !tensorboard --logdir r
